# %%
#############################################################
#AUTHOR : Khushkumar Patel (khushkumar.cba1531@ict.gnu.ac.in)
#############################################################

# IMPORT STATEMENTS
from tweepy import OAuthHandler
from tweepy import API
import time
import json

# %%
#Credentials 
#consumer_key = '*************************'
#consumer_secret = '**************************************************'

# %%
#Authenticate and With Consumer Key and Consumer Secret
auth = OAuthHandler(consumer_key, consumer_secret)
api = API(auth)

# %%
#Name of Twitter Handle
screen_name = '@midasIIITD'

# %%
tweets = api.user_timeline(screen_name=screen_name, count=300, tweet_mode='extended')

# %%
#Method to Get No of Images in Tweet
def getMediaCount(jsonObj):
    key = 'extended_entities'
    if key in jsonObj._json.keys():
        return len(jsonObj._json['extended_entities']['media'])
    else:
        return None

#Method to Change the Twitter time stamp to YYYY-MM-DD HH:MM:SS
def getDateTime(jsonObj):
    return time.strftime('%Y-%m-%d %H:%M:%S', time.strptime(jsonObj._json['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))

# %%
#Printing List
for tweet in tweets:  
    print('-'*10)
    print("Tweet Text :: ", tweet._json['full_text'])
    print("Created Datetime :: ", getDateTime(tweet))
    print("Likes Count :: ", tweet._json['favorite_count'])
    print("Retweet Count :: ", tweet._json['retweet_count'])
    print("No of Images :: ", getMediaCount(tweet))
    print('*'*10)
# Out:
# ----------
# Tweet Text ::  @IEEEBigMM19 is also available on Facebook now.
# LIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular updates.
# Check more details at https://t.co/w9ZymoPisk
#
# #IEEE #BigMM19 #Big #Multimedia #Singapore
# Created Datetime ::  2019-03-20 08:19:24
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/I4vqf8FE6K …
# When: Sep 11, 2019 - Sep 13, 201…
# Created Datetime ::  2019-03-20 02:40:07
# Likes Count ::  0
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals
#
# https://t.co/oUq2G0UgKN
#
# When: Sep 11, 2019 - Sep 13, 2019
# Where: Singapore
# Submission Deadline: Apr 1, 2019
# Notification Due: Apr 10, 2019
#
# #IEEE #BigMM #Workshop #Proposal #Singapore #Multimedia
# Created Datetime ::  2019-03-18 02:27:47
# Likes Count ::  6
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.
# Created Datetime ::  2019-03-17 14:22:04
# Likes Count ::  15
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same.
#
# If you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching.
#
# #MIDAS #Summer #Research #Internship
# Created Datetime ::  2019-03-16 14:06:56
# Likes Count ::  6
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  IEEE BigMM 2019 - Call for Workshop Proposals.
#
# Contact @midasIIITD @RatnRajiv @debanjanbhucs if you have any query.
#
# Deadlines:
# - Proposals due: April 1, 2019
# - Acceptance notification: April 10, 2019
#
# Further information:
# - Webpage: https://t.co/5XX5Wyxp5T
#
# #IEEE #BigMM19
# Created Datetime ::  2019-03-16 09:20:29
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment".
#
# Check more details at https://t.co/i6eAHg7gcN
#
# #MeToo #Student #Research  #Paper #NAACL
# Created Datetime ::  2019-03-16 09:14:58
# Likes Count ::  7
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.
# Created Datetime ::  2019-03-16 05:13:14
# Likes Count ::  7
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th…
# Created Datetime ::  2019-03-13 17:09:44
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot
# We need to clearly mention abstract and final submission deadlines at https://t.co/U7DTNNyw87
#
# Currently, we have just mentioned 1st April as the regular paper submission deadline. Kindly update.
#
# #ACMMM19 #Nice #Multimedia https://t.co/ocOCrlFHLH
# Created Datetime ::  2019-03-13 04:11:24
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…
# Created Datetime ::  2019-03-13 04:06:04
# Likes Count ::  0
# Retweet Count ::  13
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBuslaev @creaf @viglovikov and @cvtalks | https://…
# Created Datetime ::  2019-03-12 17:43:44
# Likes Count ::  0
# Retweet Count ::  67
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Awesome members of our @midasIIITD team who are working on Humonics projects. Great to have you on our team.
#
# #team #research #AI #ML #projects https://t.co/lN7hItwPO9
# Created Datetime ::  2019-03-12 14:37:55
# Likes Count ::  16
# Retweet Count ::  4
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  @saanidhi @ACMMM19 Before Friday, 15th March.
# Created Datetime ::  2019-03-11 14:58:30
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We are glad to inform that Adobe is launching Women’s day Tech-Challenge to hire female engineers from 2019 Batch under our #SheCodes initiative.
# Please register here for participating in the challenge at https://t.co/DjkKCJHDBC
#
# Check full details at https://t.co/5ArLu3icva
# Created Datetime ::  2019-03-11 12:02:42
# Likes Count ::  4
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We will email tasks to all shortlisted candidates for an internship at @midasIIITD by Friday, 15th March. If you are shortlisted and did not hear from us by that time then kindly drop an email to us.
#
# Looking forward to working with you.
#
# #research #Internship #AI @ACMMM19
# Created Datetime ::  2019-03-11 11:54:38
# Likes Count ::  3
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less than three weeks are left for @ACMMM19 submission.
# Looking forward to your contribution to #ACMMM and see you in Nice, France.
# @midasIIITD @iiit_hyderabad @iitdelhi @abhinavdhall @iitmadras @iiscbangalore @IITKanpur @iitbombay @iitkharagpur @IITJodhpur @iitropar @IIITDelhi
# Created Datetime ::  2019-03-11 06:22:12
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Face Recognition using One-Shot Learning – #DeepLearning
# using DL architecture that works great with one-shot learning calle…
# Created Datetime ::  2019-03-11 06:17:20
# Likes Count ::  0
# Retweet Count ::  64
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @AvinashSwamina2 @IIITDelhi No. They will be given tasks along with students who will be selected in the second round.
# Created Datetime ::  2019-03-08 13:22:07
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We are in the process of finalizing the shortlisted candidates for internship at @midasIIITD which we have received in the second round.
# We will assign tasks to all shortlisted candidates around early next week. We are also delaying the task since DTU has mid-sem until 15 March.
# Created Datetime ::  2019-03-08 13:15:34
# Likes Count ::  8
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ylecun @NilayShri @the_dhumketu @debanjanbhucs will it be useful?
# Created Datetime ::  2019-03-06 13:44:11
# Likes Count ::  3
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Python Data Science for Beginners https://t.co/yRExdmdZGh https://t.co/vRqTRuayO3
# Created Datetime ::  2019-03-06 11:12:30
# Likes Count ::  0
# Retweet Count ::  22
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @stanfordnlp: Useful feature of our Python stanfordnlp: get lemmas &amp; morphology in many languages. Le ski de fond touché→lemma toucher f…
# Created Datetime ::  2019-03-03 19:36:04
# Likes Count ::  0
# Retweet Count ::  35
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @NilayShri @NilayShri, Certain thing! The next team outing will be for lipreading team.
# Probably, just after @ACMMM19 submission.
# Created Datetime ::  2019-03-03 17:09:48
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  At @midasIIITD, we not only work hard but also have fun.
# Today, we had a team (for Humonics sponsored projects) outing at Pirates of Grill. It was a wonderful day with lots of fun.
#
# #fun #lunch #MIDAS https://t.co/MEVA1NfHRd
# Created Datetime ::  2019-03-03 15:37:28
# Likes Count ::  9
# Retweet Count ::  1
# No of Images ::  3
# **********
# ----------
# Tweet Text ::  Considering several requests to extend the deadline for internship application, @midasIIITD at @IIITDelhi has decided that we will open the internship form https://t.co/t54AZ9eo26 again on March 7 and process all application received by March 8, 10 am.
#
# #research #Internship #AI
# Created Datetime ::  2019-03-03 14:55:31
# Likes Count ::  6
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @jeremyphoward: 39 studies about human perception in 30 minutes by @kennelliott
#
# Awesome article. If you do any visualization or comput…
# Created Datetime ::  2019-03-03 14:26:40
# Likes Count ::  0
# Retweet Count ::  315
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Correction:   @midasIIITD at @IIITDelhi
# Created Datetime ::  2019-03-02 17:43:05
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Thanks much to all aspirants who have applied for the summer internship 2019 at @midasIIITD at @midasIIITD. We have received over 200 applications. Thus, many good applications are not selected for next round. We have sent emails to all candidates, kindly check that for results.
# Created Datetime ::  2019-03-02 09:59:03
# Likes Count ::  7
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Keras Hyperparameter Tuning in Google Colab Using Hyperas https://t.co/hmaI4ukJRX https://t.co/s3nTqqgnAb
# Created Datetime ::  2019-02-28 14:21:21
# Likes Count ::  0
# Retweet Count ::  4
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Great meeting with @midasIIITD alumnus, Sanket Jain today.
# He was among first MTech students who worked with me at @IIITDelh…
# Created Datetime ::  2019-02-26 18:30:52
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Correction: They have published the following paper only:
#
# PROMPT: Personalized User Tag Recommendation for Social Media Photos Leveraging Personal and Social Contexts.
# Created Datetime ::  2019-02-26 03:40:22
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  We will process all applications received by March 1, 2019 and notify all shortlisted candidates by March 3.
#
# If you have not applied yet for @midasIIITD internship then you may do so by filling the form https://t.co/t54AZ9eo26
#
# #MIDAS #IIITD #Internship #NLP #ML #AI #DL #CV
# Created Datetime ::  2019-02-25 16:10:46
# Likes Count ::  2
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @ecsquendor: Jit Ghosh discusses the "GloVe" 2014 Stanford paper on word embeddings. This one was a great session! #paperreviewcalls #nl…
# Created Datetime ::  2019-02-24 03:39:40
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @goodfellow_ian: This CVPR workshop is looking for applications of computer vision in developing countries. You don't need to submit a f…
# Created Datetime ::  2019-02-23 15:41:27
# Likes Count ::  0
# Retweet Count ::  90
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @IIITDelhi: PhD Admission 2019 are open now
#
# Online applications starts from 20th February 2019 and the last date to apply is 14th March…
# Created Datetime ::  2019-02-22 11:54:49
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: #AI for Social Good study - how to inform policy, achieve interpretability, reduce bias and more -
# include review of global…
# Created Datetime ::  2019-02-21 16:27:54
# Likes Count ::  0
# Retweet Count ::  13
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @IIITDelhi has initiated PhD Admission 2019 process (Regular Round).
#
# Online applications start from 20th February 2019 and the last date to apply is 14th March 2019.
#
# For more details please visit the following link: https://t.co/qWa9I7CFqX.
#
# #IIITD #PhD #Admission
# Created Datetime ::  2019-02-21 06:39:27
# Likes Count ::  2
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @radamihalcea: We tend to focus mainly on creating learning algorithms, and yet there is so much that can be gained from unlearning. In…
# Created Datetime ::  2019-02-21 04:48:24
# Likes Count ::  0
# Retweet Count ::  13
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @RealAAAI @RatnRajiv Thanks, @RealAAAI for recognizing our efforts.
#
# Congratulations, @midasIIITD students for winning Best Student Poster award at 33rd AAAI Conference on Artificial Intelligence.
#
# Many thanks to authors, Raghav, @the_dhumketu Kshitij, @RatnRajiv @ponguru and Roger.
#
# #AAAI19 #AI https://t.co/oKy1OYCOAR
# Created Datetime ::  2019-02-20 07:09:19
# Likes Count ::  4
# Retweet Count ::  1
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  Deepak Gupta, has joined @Google today.
# Earlier this week, Anupam Samanta, has also joined Google.
# Both will be working at Google office in Mount View, California, USA. Having immense pride to see their success.
#
# They have published two papers with @midasIIITD head @RatnRajiv https://t.co/QEiIs5nTSn
# Created Datetime ::  2019-02-20 05:38:29
# Likes Count ::  4
# Retweet Count ::  2
# No of Images ::  2
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: We are pleased to announce the multimedia Grand Challenges that will be offered at ACM Multimedia in 2019. Check out the list;…
# Created Datetime ::  2019-02-19 17:16:24
# Likes Count ::  0
# Retweet Count ::  15
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  In addition to projects related to NLP and Multimedia systems, we have open positions for 3D animation interns too.
# Candidate should have knowledge of Maya character animation, modeling, and good drawing skills.
#
# To apply, fill https://t.co/t54AZ9eo26
# and mention "3D Animation"
# Created Datetime ::  2019-02-19 04:29:33
# Likes Count ::  3
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @technology: What could the manufacturing industry teach healthcare?
# Created Datetime ::  2019-02-19 04:19:05
# Likes Count ::  0
# Retweet Count ::  292
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @MSFTResearch: Dr. Layla El Asri wants you to be able to talk to your machine just like you’d talk to another person. That’s the easy pa…
# Created Datetime ::  2019-02-19 04:18:53
# Likes Count ::  0
# Retweet Count ::  22
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  To apply for @midasIIITD internship at @IIITDelhi, fill the following form: https://t.co/t54AZ9eo26
#
# Check more details at https://t.co/GvP3wsWtzX
#
# Pls share @debanjanbhucs @RatnRajiv @the_dhumketu @Hitkul_ @NilayShri
#
# #Research #Internship #Multimedia #NLP #ML #DeepLearning
# Created Datetime ::  2019-02-18 17:29:44
# Likes Count ::  11
# Retweet Count ::  9
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @CornellDyson: Digital ag is Cornell’s newest radical collaboration initiative→https://t.co/hVXSnoSbnS
# #DigitalAg #Cornell @CornellNews…
# Created Datetime ::  2019-02-18 05:37:59
# Likes Count ::  0
# Retweet Count ::  6
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @odsc: Introduction to StanfordNLP: a state-of-the-art NLP library for 53 languages @StanfordNLP #DataScience #NLP #NaturalLanguageProce…
# Created Datetime ::  2019-02-17 17:22:06
# Likes Count ::  0
# Retweet Count ::  51
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Looking forward to your participation in Multimedia Grand Challenges of @ACMMM19
#
# Several interesting challenges are available at https://t.co/mGYxuvrve5
#
# @midasIIITD lab is looking forward to helping students from Indian institutes who plan to participate.
#
# #ACMMM #Multimedia
# Created Datetime ::  2019-02-17 09:02:28
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Consider attending National Workshop on Intelligent Multimodal Interfaces (NWIMI) at Indian Institute of Technology Jodhpur @IITJodhpur from March 9-10, 2019.
#
# Check more details at https://t.co/lLLzl0dUaI
# Created Datetime ::  2019-02-17 08:49:36
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Submissions are invited for a special issue of Cognitive Computation (Impact Factor: 3.479) on Affect Recognition in Multimodal Language.
#
# CFP - https://t.co/vP2Naq1C85
#
# Submission deadline - 05/05/2019
#
# Contact @soujanyaporia for further details.
# Created Datetime ::  2019-02-17 06:39:30
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: https://t.co/qNFzJ7ZHki
# Created Datetime ::  2019-02-16 16:57:51
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @MSFTResearch: Congratulations to Manik Varma, @iitdelhi's Himanshu Jain, Venkatesh Balasubramanian and Bhanu Chunduri for winning the B…
# Created Datetime ::  2019-02-15 08:22:23
# Likes Count ::  0
# Retweet Count ::  13
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations! Anupam Samanta on joining @Google as a software engineer.
#
# Anupam worked with @midasIIITD head, Dr @RatnRajiv and published two research papers. Great to hear that Anupam got ML and Data Science team in Google due to his research experience and publications. https://t.co/IcuBbjEkjc
# Created Datetime ::  2019-02-14 15:56:14
# Likes Count ::  14
# Retweet Count ::  4
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Using BERT for state-of-the-art pre-training for natural language processing https://t.co/wAyERwPw3r https://t.co/ghPTpClh3p
# Created Datetime ::  2019-02-13 18:56:13
# Likes Count ::  0
# Retweet Count ::  5
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: Attention authors of ACM MultiMedia 2018 and 2017 main conference papers. Submit a reproducibility paper to ACMMM 2019 https:/…
# Created Datetime ::  2019-02-13 15:54:52
# Likes Count ::  0
# Retweet Count ::  11
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: 9 Must-have skills you need to become a Data Scientist, updated https://t.co/OeeComtoWu https://t.co/DGq5qrQefc
# Created Datetime ::  2019-02-13 05:56:05
# Likes Count ::  0
# Retweet Count ::  11
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  @ACMMM19 @ACM Just one week is left for workshop proposal. Kindly consider submitting it.
# @midasIIITD @abhinavdhall @IIITDelhi @iiit_hyderabad @iitdelhi @IITKanpur @iiscbangalore @IITKgp @debanjanbhucs @the_dhumketu @RatnRajiv @fire_forum @iitmadras @soujanyaporia @NTUsg @iitbombay #ACMMM19
# Created Datetime ::  2019-02-07 19:21:52
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @NilayShri @the_dhumketu Thanks, @NilayShri for sharing.
# Indeed a very good work.
# Created Datetime ::  2019-02-07 15:49:59
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @NilayShri: @midasIIITD @the_dhumketu this seems to be the 'trend' https://t.co/m6YfyTtwfX
# Created Datetime ::  2019-02-07 15:49:08
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Machine Learning in Python by @PyImageSearch
# "Struggling to get started with machine learning using Python? In this step-by-…
# Created Datetime ::  2019-02-07 06:23:10
# Likes Count ::  0
# Retweet Count ::  53
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Cambridge_Uni: .@DeepMindAI and @Cambridge_Trust  are offering scholarships to under-represented students to study computer science. Op…
# Created Datetime ::  2019-02-06 11:26:25
# Likes Count ::  0
# Retweet Count ::  35
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @GoogleAI: Google AI  and @DeepMindAI researchers have open-sourced the Hanabi Learning Environment, a testbed for collaborative multi-a…
# Created Datetime ::  2019-02-05 18:32:54
# Likes Count ::  0
# Retweet Count ::  211
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Edit: In the updated leaderboard we are now ranked 10th in the suggestion mining task! Thanks for updates @isarth23
# Created Datetime ::  2019-02-05 17:45:09
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations! @isarth23.
# It is our pleasure to work with you.
# You are a gem of @midasIIITD. https://t.co/mOJQyhd26K
# Created Datetime ::  2019-02-05 17:44:27
# Likes Count ::  4
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  In addition to OffensEval task, @midasIIITD has also performed well in the suggestion mining task (https://t.co/UiloRZiYSr) of SemEval 19.
#
# We secured 11th rank in this task.
#
# Congrats! @debanjanbhucs Raymond, Karan Uppal, @isarth23 @the_dhumketu @RatnRajiv for your hard work.
# Created Datetime ::  2019-02-05 12:09:44
# Likes Count ::  5
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Thanks, Karan Uppal and @RatnRajiv for all your support.
# Created Datetime ::  2019-02-05 11:55:41
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @midasIIITD performance in OffensEval 2019 (SemEval 2019 - Task 6).
#
# In subtask-A, we came 5th out of 103 teams
# In subtask-B, we came 8th out of 75 teams
# We are very close to best results.
#
# Congratulations! @debanjanbhucs, Raymond, @isarth23, @the_dhumketu, @LaibaMehnaz, @Simcyy https://t.co/NveQlv8wO8
# Created Datetime ::  2019-02-05 11:06:31
# Likes Count ::  4
# Retweet Count ::  3
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @ProfAnirban: One of the biggest obstacles to the adoption of #NLP and cognitive #AI is the lack of pretrained models in languages other…
# Created Datetime ::  2019-02-04 12:16:16
# Likes Count ::  0
# Retweet Count ::  39
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @IIITDelhi: Students of @midasIIITD lab won the best student poster award at 33rd @RealAAAI 2019 conference in Honolulu, Hawaii for the…
# Created Datetime ::  2019-02-04 10:58:53
# Likes Count ::  0
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @RealAAAI 2019 summary for @midasIIITD.
# 1 paper in main conference, 1 paper in EAAI, 2 papers published in student abstract and poster sessions.
# We won the best student poster award.
# 6 researchers from MIDAS lab attended the conference.
# Got several interests for collaborations. https://t.co/JVo6pRMWL1
# Created Datetime ::  2019-02-02 05:05:16
# Likes Count ::  7
# Retweet Count ::  3
# No of Images ::  4
# **********
# ----------
# Tweet Text ::  @the_dhumketu @RealAAAI Congrats! Raghav, Kshitij, and @the_dhumketu for the best student poster award!
# Congrats @RatnRajiv @ponguru and Prof Roger Zimmermann for their guidance.
#
# Have a great time in Honolulu, Hawaii, USA.
# Created Datetime ::  2019-02-01 07:46:57
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Our paper titled, "Mind Your Language: Abuse and Offence Detection for Code-Switched Languages", won the best student poster award at 33rd @RealAAAI 2019 conference in Honolulu, Hawaii, USA.
#
# Congratulations authors! Raghav, Kshitij, @the_dhumketu, @ponguru, and Roger.
#
# #AAAI19 https://t.co/e5lFJhb6bi
# Created Datetime ::  2019-02-01 07:30:53
# Likes Count ::  24
# Retweet Count ::  3
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @PeterMartigny: Very interesting talk by @ChenguangZhu2 at the @stanfordnlp seminar on SDNet, a new architecture for conversational ques…
# Created Datetime ::  2019-02-01 03:15:27
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @NilayShri: @midasIIITD @RatnRajiv
# @the_dhumketu
# https://t.co/PkUa18lF8p
# Created Datetime ::  2019-02-01 03:13:23
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  CFP for @ACMMM19 has been posted on WikiCFP. Kindly share with your colleagues and submit your work to #ACMMM 2019.
#
# https://t.co/Kgti6H4W8g
#
# Please share, @IIITDelhi @iiit_hyderabad @precog_iiitd @iitdelhi @iitbombay @IITKgp @IITKanpur @_iitg @iiscbangalore @iitropar @lcs2iiitd
# Created Datetime ::  2019-01-31 06:57:04
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @midasIIITD Lab is pleased to share our novel work titled, Harnessing GANs for Addition of New Classes in VSR (https://t.co/SdFNLNP2PR).
#
# We present a novel approach to low-shot learning that uses the idea of imagination over unseen classes in a classification problem setting.
# Created Datetime ::  2019-01-31 05:50:19
# Likes Count ::  4
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: If you are attending @RealAAAI and liked our work, Lipper, for speech reconstruction from silent videos using lipreading the…
# Created Datetime ::  2019-01-31 05:32:43
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Great to be part of this year's accepted papers at @RealAAAI from India. Out of 25 papers from India, 6 from @IIITDelhi.
# Co…
# Created Datetime ::  2019-01-30 19:46:11
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @MIT: Want to squelch fake news? Let the readers take charge https://t.co/Jusr6TMUse https://t.co/KDHmFDP9aE
# Created Datetime ::  2019-01-30 17:18:40
# Likes Count ::  0
# Retweet Count ::  11
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  If you are attending @RealAAAI 2019 at Honolulu, Hawaii, USA then attend our talk in the Student Abstract Session for very interesting work on speech reconstruction from silent videos based on lipreading.
#
# It is one of the first works of this kind.
# Looking forward to seeing you https://t.co/rODmBKSONr
# Created Datetime ::  2019-01-30 05:00:29
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 3. Lipper: Synthesizing Thy Speech using Multi-View Lipreading
# - Time: Thursday, Main Paper Session
# - Authors: @the_dhumketu, Rohit, Salik, @RatnRajiv, Yifang, and Roger
#
# 3/3
# Created Datetime ::  2019-01-29 19:42:10
# Likes Count ::  5
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 2. Lipper: Speaker Independent Speech Synthesis using Multi-View Lipreading
# - Time: Wednesday, Student Abstract Session
# - Authors: Salik, @the_dhumketu, Rohit, Swati, @RatnRajiv, and Roger
#
# 2/3
# Created Datetime ::  2019-01-29 19:39:29
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  If you are attending @RealAAAI 2019 then visit following sessions for our papers.
#
# 1. Mind Your Language: Abuse and Offense Detection on Code-Switched Languages
# - Time: Tuesday, Student Abstract Session (SAS)
# - Authors: Raghav, @the_dhumketu, Kshitij, @RatnRajiv, PK, Roger
#
# 1/3
# Created Datetime ::  2019-01-29 19:31:35
# Likes Count ::  2
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @TechAtBloomberg @debanjanbhucs It is a great experience to work with @debanjanbhucs.
# @midasIIITD looks forward to many more such works with Bloomberg.
# Created Datetime ::  2019-01-29 18:05:01
# Likes Count ::  5
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @TechAtBloomberg: Learn more about the collaborative efforts of researchers @debanjanbhucs &amp; Daniel Preoţiuc-Pietro w/ academics around…
# Created Datetime ::  2019-01-29 18:03:31
# Likes Count ::  0
# Retweet Count ::  5
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: We as researchers working at Bloomberg also get opportunities to collaborate with academia. Here are the outcomes of two…
# Created Datetime ::  2019-01-29 17:52:23
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: 7 Steps to Mastering Basic Machine Learning with Python — 2019 Edition
#  https://t.co/yZExGjOVWH https://t.co/sJC8p2kTyp
# Created Datetime ::  2019-01-29 14:52:24
# Likes Count ::  0
# Retweet Count ::  33
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  @TechAtBloomberg @debanjanbhucs @IIITDelhi @RatnRajiv Congrats, team @midasIIITD! https://t.co/ncsgSUusUb
# Created Datetime ::  2019-01-29 05:17:27
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  2
# **********
# ----------
# Tweet Text ::  RT @TechAtBloomberg: #Textanalytics researcher @debanjanbhucs joins @IIITDelhi's @RatnRajiv &amp; other co-authors to present "Get IT Scored us…
# Created Datetime ::  2019-01-29 04:40:47
# Likes Count ::  0
# Retweet Count ::  5
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Top 16 #OpenSource #DeepLearning Libraries and Platforms #KDN https://t.co/TycxmMSCWs
# Created Datetime ::  2019-01-28 12:11:29
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Princeton: Using data from more than 6,000 patients, @EPrinceton researchers applied #machinelearning methods to design a system that c…
# Created Datetime ::  2019-01-28 12:11:13
# Likes Count ::  0
# Retweet Count ::  19
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @CornellBirds: In 1929 Cornell Lab founder Arthur Allen made the very first recordings of wild birds. Follow @MacaulayLibrary as they sh…
# Created Datetime ::  2019-01-28 12:10:37
# Likes Count ::  0
# Retweet Count ::  68
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @seb_ruder: Natural Questions: A new QA dataset consisting of 300,000+ naturally occurring questions (posed to Google search) with human…
# Created Datetime ::  2019-01-25 08:56:54
# Likes Count ::  0
# Retweet Count ::  141
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: 10 More #Free Must-Read #Books for #MachineLearning and #DataScience #KDN https://t.co/EtMyAJFl6d
# Created Datetime ::  2019-01-24 15:43:25
# Likes Count ::  0
# Retweet Count ::  24
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: How to build an API for a machine learning model in 5 minutes using Flask https://t.co/VFN7NmCqTu https://t.co/oZ8rXEGM5w
# Created Datetime ::  2019-01-24 15:42:59
# Likes Count ::  0
# Retweet Count ::  25
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  @ACMMM19 @ACM @abhinavdhall consider submitting your proposal.
# Created Datetime ::  2019-01-23 10:24:14
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: Jump start your @ACM #Multimedia workshop submission... First workshop titles are now online https://t.co/S9ZSaJTH1a But also…
# Created Datetime ::  2019-01-23 10:23:34
# Likes Count ::  0
# Retweet Count ::  10
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @NUSComputing Congratulations! Yaman @the_dhumketu , Roger, Yifang, @RatnRajiv, Rohit, and Salik.
# Created Datetime ::  2019-01-22 14:04:40
# Likes Count ::  1
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  ⚡️ “Achievements”
#
# https://t.co/LvZt1GTY4C
# Created Datetime ::  2019-01-22 14:02:51
# Likes Count ::  3
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @NUSComputing: A/P Roger Zimmermann and his collaborators from IIIT Delhi developed a lipreading system that produces audio from lip mov…
# Created Datetime ::  2019-01-22 13:58:08
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Welcome one member to our @midasIIITD family, SkyWalker.
# It will strengthen our team with Falcon.
#
# #midas #server #falcon #skywalker https://t.co/u6YOBaJ7DB
# Created Datetime ::  2019-01-21 16:29:31
# Likes Count ::  9
# Retweet Count ::  1
# No of Images ::  3
# **********
# ----------
# Tweet Text ::  Dr @RatnRajiv Shah delivered a research talk in the National Symposium on Natural Languages Processing and Artificial Intelligence at the Manipal University Jaipur. He discussed different multimedia systems for society and healthcare which @midasIIITD lab is currently working on. https://t.co/cVAGyk9xAs
# Created Datetime ::  2019-01-21 15:19:33
# Likes Count ::  6
# Retweet Count ::  2
# No of Images ::  4
# **********
# ----------
# Tweet Text ::  RT @Scott__Hubbard: Don't miss this new article from @ted_dunning, who presents practical methods for near real-time monitoring of machine…
# Created Datetime ::  2019-01-21 09:33:03
# Likes Count ::  0
# Retweet Count ::  9
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kaggle: Stuck inside with stir-crazy kids? 😫🤒😵Check out these downloadable machine learning projects designed for kids aged 8-16 👉https…
# Created Datetime ::  2019-01-21 09:32:03
# Likes Count ::  0
# Retweet Count ::  37
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @Princeton @nyuniversity @nytimes Team @midasIIITD, do we have the same trend in India?
# Created Datetime ::  2019-01-21 06:54:14
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Harvard: Researchers find connections between worry and the development of heart disease https://t.co/yQ4miy8DHI
# Created Datetime ::  2019-01-20 05:49:19
# Likes Count ::  0
# Retweet Count ::  77
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Stanford: Researchers across Stanford are exploring ways to predict and prevent preterm births, and to improve care for the highest-ris…
# Created Datetime ::  2019-01-19 18:15:35
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Meet our members of @midasIIITD .
#
# https://t.co/2PFbtoDtDR
#
# We welcome new members to our group.
#
# MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.
#
# #multimedia #research #lab
# Created Datetime ::  2019-01-19 09:59:16
# Likes Count ::  7
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: How to Monitor Machine Learning Models in Real-Time https://t.co/9UpYVzlQWI https://t.co/9lK9eoOVWe
# Created Datetime ::  2019-01-19 03:27:33
# Likes Count ::  0
# Retweet Count ::  9
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  Congratulations! @Leomi7 @ashualloy @RatnRajiv Ayush, Himanshu, Aditya, Deepanshu, @isarth23 @rgrgrajat1
# Created Datetime ::  2019-01-18 10:25:41
# Likes Count ::  6
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @jasonbaumgartne: #Pushshift is happy to announce a new dataset for your ML / NLP / Research pleasure -- Data for over 340+ Stackexchang…
# Created Datetime ::  2019-01-18 10:17:02
# Likes Count ::  0
# Retweet Count ::  20
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Proceedings of FIRE 2018 is online now at https://t.co/vzLpwVp1Qb
# Our 4 papers are:
# 1. Fully Automatic Approach to Identify Factual or Fact-checkable Tweets
# 2. Multilingual Author Profiling from SMS
# 3. NMT based Tamil Translation
# 4. Named Entity Recognition for Indian Languages
# Created Datetime ::  2019-01-18 10:16:26
# Likes Count ::  10
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @hseas: Only 20 percent of pediatric cancer patients in lower- and middle-income countries will survive. Engineering students partnered…
# Created Datetime ::  2019-01-17 04:04:16
# Likes Count ::  0
# Retweet Count ::  27
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Cornell: Can virtual reality transform medicine? Psychologist JoAnn Difede @WeillCornell began using #VR with soldiers and survivors fr…
# Created Datetime ::  2019-01-17 04:03:55
# Likes Count ::  0
# Retweet Count ::  11
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Explainable Artificial Intelligence https://t.co/rllNxnm73U https://t.co/mAYFPMJF8P
# Created Datetime ::  2019-01-13 16:45:48
# Likes Count ::  0
# Retweet Count ::  20
# No of Images ::  2
# **********
# ----------
# Tweet Text ::  @abhinavdhall @RatnRajiv Emailed you.
# Created Datetime ::  2019-01-13 16:40:46
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: A comprehensive list of #MachineLearning Resources: Open Courses, Textbooks, #Tutorials, Cheat Sheets and more #KDN https://…
# Created Datetime ::  2019-01-13 16:03:25
# Likes Count ::  0
# Retweet Count ::  40
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Call for Book Chapter- Springer- Deep learning based approaches for sentiment analysis. Contact for more details.
#
# Important Dates:
#
# Abstract: Jan 15, 2019
# Notification: Jan 31
# Full chapter:  April 15
# First review: May 15
# Final notification: June 30
# Camera Ready: July 15
# Created Datetime ::  2019-01-13 07:19:19
# Likes Count ::  6
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Stanford: The average woman is exposed to four medications during her pregnancy and over 80 percent of medications haven’t been studied…
# Created Datetime ::  2019-01-12 14:37:07
# Likes Count ::  0
# Retweet Count ::  48
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @harvardmed @Harvard Another interesting direction to our previous work @MADAIguy @Leomi7
# Created Datetime ::  2019-01-10 08:51:20
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @harvardmed: A first-of-its-kind strategy aims to improve outcomes for kidney cancer patients who are at high risk of recurrence followi…
# Created Datetime ::  2019-01-10 08:50:35
# Likes Count ::  0
# Retweet Count ::  27
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Fortunate to have appreciation from my former NUS professor, Dr. Terence Sim.
# He also appreciated our @RealAAAI
# 2019 paper o…
# Created Datetime ::  2019-01-10 08:48:17
# Likes Count ::  0
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @Harvard: The study provides potential future targets for drug development to treat osteoporosis https://t.co/YhfrOovdbO
# Created Datetime ::  2019-01-09 02:05:06
# Likes Count ::  0
# Retweet Count ::  9
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @UniofOxford: In the final episode of series one of our Futuremakers podcast series, hear from Professor Sir @Nigel_Shadbolt on where th…
# Created Datetime ::  2019-01-07 09:05:12
# Likes Count ::  0
# Retweet Count ::  16
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19: Call for Workshop Proposals
#
# Deadline: Friday 15 February 2019
#
# https://t.co/vpdx97ucNP
#
# #ACMMM19 #Multimedia #Research #Nice #France
# Created Datetime ::  2019-01-06 12:54:06
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19: Call for Grand Challenge Proposals
#
# Deadline: Tuesday 8 January 2019
#
# Check more details at-  https://t.co/uT3bFAsjfU
#
# #ACMMM #Multimedia #Research #Nice
# Created Datetime ::  2019-01-06 04:29:25
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Since 1993, ACM Multimedia has been bringing together researchers and practitioners from academia and industry to present innovative research results and discuss recent advancements.
#
# Check @ACMMM19 website for more details:
# https://t.co/QroXuO8ZAV
#
# #ACMMM #Multimedia #Research
# Created Datetime ::  2019-01-06 04:09:54
# Likes Count ::  5
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19 is structured around four themes (alphabetical):
#
# Engaging users with multimedia
# Multimedia experience
# Multimedia systems
# Understanding multimedia content
#
# Multimedia research focuses on integration of the multiple perspectives offered by different digital modalities.
# Created Datetime ::  2019-01-06 04:07:29
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  ACM Multimedia 2019: First Call for Papers/Call for Contributions
# @ACMMM19 is the premier international conference in the area of multimedia within the field of computer science.
# Details on the conference themes are available on the conference website:
# https://t.co/QroXuO8ZAV
# Created Datetime ::  2019-01-06 04:05:38
# Likes Count ::  4
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: Happy new year! 2019 started with a bang. Thanks to everyone working to help resolve the ACM webserver hack issues. Please wat…
# Created Datetime ::  2019-01-03 06:14:05
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  You may follow @midasIIITD updates through following:
#
# Website: https://t.co/sPvbKhflKQ
# Facebook: https://t.co/yMDAL2pof0
# LinkedIn: https://t.co/ZPNNnLTi8Z
#
# We look forward to producing some groundbreaking work in 2019 which can help society through ML and Multimedia Processing.
# Created Datetime ::  2019-01-01 17:21:49
# Likes Count ::  4
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Today, @midasIIITD completed one year at @IIITDelhi. In last one year, we have shown our strong presence in research communities of top-tier conferences and journals through our world-class research. This could not have been possible without the hard work of MIDAS researchers. https://t.co/zCdQr8Zfwe
# Created Datetime ::  2019-01-01 17:17:56
# Likes Count ::  14
# Retweet Count ::  5
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: Happy anniversary to @midasIIITD . It surely has been a productive year for us and hope to see some ground breaking work…
# Created Datetime ::  2019-01-01 16:14:24
# Likes Count ::  0
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Two Research Assistant (RA) positions are still open. Contact us if you are eligible and interested to work on the mentioned projects.
#
# PS: RAs are full-time jobs. Only apply if you have finished your studies.
# Created Datetime ::  2018-12-27 10:28:31
# Likes Count ::  2
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Positions for two Research Assistants (RA) are still open at @midasIIITD. Interested candidates may send their CV at midas AT https://t.co/ey7h1zgmKD
# PS: RAs are full-time positions. Thus, only candidates who have finished their study are requested to apply.
# #MIDAS #Humonics #RA
# Created Datetime ::  2018-12-27 09:59:06
# Likes Count ::  5
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @TCoolsIT: I wrote a blogpost on CoreNLP highlighting some of its functionality. If you want a quick dip before diving into the course,…
# Created Datetime ::  2018-12-27 02:33:58
# Likes Count ::  0
# Retweet Count ::  12
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @RatnRajiv delivered a research talk at the Central Research Laboratories of NEC Corporation, Japan. He discussed several multimedia systems for society and healthcare. He had interesting pre and post-talk discussions on multimedia systems for cybersecurity that can help society. https://t.co/itWHzv0ias
# Created Datetime ::  2018-12-26 09:41:04
# Likes Count ::  14
# Retweet Count ::  2
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  @midasIIITD look forward to work together. https://t.co/nrpf32ODo2
# Created Datetime ::  2018-12-25 04:15:15
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @the_dhumketu @punnibhai @Hitkul_, FYI. https://t.co/yZb9mdr6IB
# Created Datetime ::  2018-12-25 03:00:21
# Likes Count ::  2
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @iiit_hyderabad: KCIS Distinguished Lecture by Andrew Zisserman on Learning from Sight and Sound. Three-time Marr Prize winner Zisserman…
# Created Datetime ::  2018-12-24 07:39:21
# Likes Count ::  0
# Retweet Count ::  12
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @StanfordAILab: Our latest blog post is out!
#
# Check it out for a recording and summary of highlights from the event "AI and the Future…
# Created Datetime ::  2018-12-21 03:50:39
# Likes Count ::  0
# Retweet Count ::  32
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @medialab: In two new papers, @PratikShahPhD and collaborators present novel #AI and machine learning methods to improve diagnosis at th…
# Created Datetime ::  2018-12-20 18:05:35
# Likes Count ::  0
# Retweet Count ::  8
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Wonderful get together with our NII colleagues. Prior to that we had a wonderful talk with Prof Chua Tat-Seng from National…
# Created Datetime ::  2018-12-20 06:14:52
# Likes Count ::  0
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19 is the premier international conference in the area of multimedia within the field of computer science. Multimedia research focuses on integration of the multiple perspectives offered by different digital modalities including images, text, video, music, and sensor data. https://t.co/8RPzQHnB34
# Created Datetime ::  2018-12-19 02:16:31
# Likes Count ::  2
# Retweet Count ::  3
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  Feel free to contact us if you have any query on @ACMMM19. We look forward to your submissions to ACM Multimedia conference 2019.
#
# Check more details on submission at https://t.co/xA2jk0KPPC
#
# #Multimedia #Research #ACMMM2019 #Nice
# Created Datetime ::  2018-12-18 14:42:27
# Likes Count ::  3
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @NilayShri @RatnRajiv @ACMMM19 Looking forward to your paper to @ACMMM19.
# Created Datetime ::  2018-12-18 14:27:12
# Likes Count ::  3
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @midasIIITD head, Dr. @RatnRajiv appointed as one of the publicity co-chairs for @ACMMM19. ACM Multimedia is the premier conference for Multimedia research. We look forward to supporting a large number of submissions to https://t.co/QroXuO8ZAV this year from India.
#
# #Multimedia
# Created Datetime ::  2018-12-18 14:15:32
# Likes Count ::  12
# Retweet Count ::  5
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @ACMMM19 @the_dhumketu fill the volunteer form for reviewer.
# Created Datetime ::  2018-12-18 12:34:10
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @ACMMM19: New in 2019! Volunteer to serve as ACM Multimedia Area Chair or Reviewer. Please provide information on your qualifications in…
# Created Datetime ::  2018-12-18 12:33:42
# Likes Count ::  0
# Retweet Count ::  7
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @IIITDelhi: Congratulations! authors Yaman @the_dhumketu, @RatnRajiv, and team @midasIIITD for winning the best poster runner-up at 20th…
# Created Datetime ::  2018-12-18 04:38:35
# Likes Count ::  0
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Best wishes to @midasIIITD students @_himanshu0113, @Hitkul_, and Shivangi on starting their research internship at National Institute of Informatics (NII), Tokyo, Japan. They will be working with our collaborators Prof Yu and Prof Satoh for six months.
#
# #internship #tokyo #nii https://t.co/JwWA8D9uHH
# Created Datetime ::  2018-12-17 16:57:00
# Likes Count ::  14
# Retweet Count ::  4
# No of Images ::  2
# **********
# ----------
# Tweet Text ::  RT @MIT: Computer model could improve human-machine interaction, provide insight into how children learn language. https://t.co/ToQo6GTMcG…
# Created Datetime ::  2018-12-17 15:05:44
# Likes Count ::  0
# Retweet Count ::  20
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Great @Wired interview with Geoff #Hinton on #AI risks, explanation, Graphcore chips, brain vs neural nets, and why there wi…
# Created Datetime ::  2018-12-17 14:37:00
# Likes Count ::  0
# Retweet Count ::  20
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @harvardmed: A defective metabolic pathway in aging immune cells may explain why the elderly commonly experience weakened immunity https…
# Created Datetime ::  2018-12-17 14:05:47
# Likes Count ::  0
# Retweet Count ::  167
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @stanfordnlp: Thread on (neural) reasoning. 👇 https://t.co/kyJs5xztwA
# Created Datetime ::  2018-12-16 15:01:20
# Likes Count ::  0
# Retweet Count ::  10
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations! Yaman @the_dhumketu, Rohit, Salik, Yifang, Roger, @RatnRajiv for winning the best poster runner-up in 20th IEEE International Symposium on Multimedia (ISM) conference in Taichung, Taiwan.
#
# Great work team @midasIIITD MIDAS and @IIITDelhi.
#
# #multimedia #ieee #ism https://t.co/zZk21IBAS1
# Created Datetime ::  2018-12-12 03:56:19
# Likes Count ::  16
# Retweet Count ::  3
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  Yaman @the_dhumketu presented our idea of reconstructing speech from silent videos based on lip movements in the "Brave New Idea" session of ACM Multimedia 2018 in Seoul, South Korea.
# A proud moment for @midasIIITD since it is one of the only five selected papers.
# #Congrats https://t.co/vEN9WFwMJQ
# Created Datetime ::  2018-12-01 15:24:51
# Likes Count ::  20
# Retweet Count ::  4
# No of Images ::  2
# **********
# ----------
# Tweet Text ::  Several Research Assistant and Intern positions are available at @midasIIITD lab. Check https://t.co/tfdisnpfw1 for more details.
#
# #RA #internship #research #ML #ComputerVision #SpeechProcessing https://t.co/vaTjL3yk9S
# Created Datetime ::  2018-11-21 04:08:34
# Likes Count ::  11
# Retweet Count ::  10
# No of Images ::  3
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Variational Autoencoders Explained – Towards Data Science https://t.co/g2HC2ne5DW https://t.co/CHkAMeYoNz
# Created Datetime ::  2018-11-20 09:05:09
# Likes Count ::  0
# Retweet Count ::  10
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  Positions for research assistants and interns are open at the @midasIIITD Lab. Check https://t.co/tfdisn7E7r for more details.
#
# Check more details of MIDAS at https://t.co/pibbLXnvMh
#
# Last date: 28 Nov 2018
#
# #RA #MIDAS #Opening #Internship
# Created Datetime ::  2018-11-19 10:23:49
# Likes Count ::  2
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations @Leomi7 Meghna, @punnibhai Puneet, @RatnRajiv, and Dr. Shree Gopal Sharma for getting your paper, Exploring Classification of Histological Disease Bio-markers from Renal Biopsy Images, accepted to IEEE Winter Conference on Applications of Computer Vision (WACV). https://t.co/ho0IH1xcD0
# Created Datetime ::  2018-11-05 19:33:31
# Likes Count ::  7
# Retweet Count ::  2
# No of Images ::  4
# **********
# ----------
# Tweet Text ::  Application for Ph.D. admission at @IIITDelhi is open now.
# Check more details at https://t.co/qZ21U9ugwg.
# Deadline: 16 Nov
# #PhD #Admission #IIITD
# Created Datetime ::  2018-11-02 04:31:26
# Likes Count ::  4
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @NirantK: 1/n The Wonderful World of Fine Tuned Language Models. Thread👇
# Created Datetime ::  2018-11-02 04:08:47
# Likes Count ::  0
# Retweet Count ::  40
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @the_dhumketu: My 2 full papers and 2 student papers selected in @RealAAAI !!
# @midasIIITD Rocks!!
# Thanks @RatnRajiv , @debanjanbhucs
# #…
# Created Datetime ::  2018-11-01 03:20:32
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @the_dhumketu @sundarpichai @GoogleAI @Googleorg @RatnRajiv We will be very happy to contribute for the same.
# The theme of our lab @midasIIITD is the same, AI for social good.
# Hope to work with @GoogleAI for the same.
# Created Datetime ::  2018-10-31 04:49:32
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Two @midasIIITD interns, @Leomi7 and Sahil Chopra, are attending EMNLP 2018 to present our papers. Best wishes to them for their first and the best NLP conference visit.
#
# #EMNLP #WASSA @SMM4H #AWL #WMT #NLP #Interns #Research
# Created Datetime ::  2018-10-29 08:47:07
# Likes Count ::  9
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Need Help Getting Started with Applied Machine Learning? All ML beginners should go through it first.
#
# https://t.co/ORpdNPubOw
#
# Thanks, @Hitkul_ for sharing.
# Created Datetime ::  2018-10-28 03:25:51
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Two student papers got accepted at AAAI despite this year 70% more submissions and the number of accepted papers same than the last year.
# 1. Mind your Language: Abuse and Offense Detection for Code-Switched Languages
# 2. Lipper: Speaker Independent Lipreading
# Congrats @midasIIITD
# Created Datetime ::  2018-10-28 02:48:34
# Likes Count ::  14
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Another #ACMMM18 paper titled, "Learning and Fusing Multimodal Deep Features for Acoustic Scene Categorization", is online now at https://t.co/uVATECqxVT
#
# #ACMMM18 #ACMMM #Multimedia #MIDAS
# Created Datetime ::  2018-10-24 11:41:59
# Likes Count ::  4
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Our paper on "Harnessing AI for Speech Reconstruction using Multi-view Silent Video Feed" is online now at https://t.co/dHex1leFw8
#
# You may see the demo at https://t.co/SIpbFRhonq
#
# #ACMMM18 #ACMMM #Multimedia #MIDAS
# Created Datetime ::  2018-10-24 11:39:32
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: One of our papers on "Detection of Personal Intake of Medicine from Twitter" published in IEEE Intelligent Systems Journ…
# Created Datetime ::  2018-10-22 03:54:29
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Training Neural Nets on Larger Batches: Practical Tips for 1-GPU, Multi-GPU &amp; Distributed setups
# https://t.co/nAELMYGCie
# Created Datetime ::  2018-10-17 09:07:33
# Likes Count ::  4
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @smnh_azadi @goodfellow_ian FYI, @the_dhumketu
# Created Datetime ::  2018-10-17 07:10:25
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @smnh_azadi: Apply this simple rejection sampling technique to get rid of the bad samples generated by your GAN model. https://t.co/Mcfi…
# Created Datetime ::  2018-10-17 07:09:47
# Likes Count ::  0
# Retweet Count ::  45
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @UniofOxford @turinginst Check @Leomi7 @punnibhai
# Created Datetime ::  2018-10-17 07:08:59
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @soujanyaporia: We are making available a large multimodal multiparty dataset, manually annotated for emotion and sentiment. With D. Haz…
# Created Datetime ::  2018-10-17 07:07:43
# Likes Count ::  0
# Retweet Count ::  16
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Thank you, Dr. Debanjan Mahata @debanjanbhucs https://t.co/vXGHxkd2T3
# Created Datetime ::  2018-10-16 17:45:30
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @mr2amc: Dear Colleagues,
#
# 3 more days to go.
# @mr2amc  Deadline extended until Oct 18 Please consider submitting your research contribu…
# Created Datetime ::  2018-10-16 03:44:19
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @AKASH_2907: My internship experience @midasIIITD during summer 2018.
# “Content-based Video Relevance Prediction” https://t.co/rqovlLUSI7
# Created Datetime ::  2018-10-15 11:09:59
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @AKASH_2907 @AKASH_2907, it was great having you at @midasIIITD.
# We hope it was a great learning experience for you.
# We wish your submitted paper will get accepted soon.
# Created Datetime ::  2018-10-15 11:09:53
# Likes Count ::  0
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  The demo of our MyLipper system which got accepted to the 20th IEEE International Symposium on Multimedia 2018 conference is as follows: https://t.co/SIpbFQZNvS.
#
# Thank you, @the_dhumketu , Rohit, and Salik for the great work.
#
# #Demo #MyLipper #ISM #MIDAS #IIITD #Multimedia
# Created Datetime ::  2018-10-13 13:50:07
# Likes Count ::  5
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations Yaman @the_dhumketu, Rohit, Salik, and Dr. Shah @RatnRajiv on getting their paper titled, "MyLipper : A Personalized System for Speech Reconstruction using Multi-View Visual Feeds", accepted to the 20th IEEE International Symposium on Multimedia (ISM) conference.
# Created Datetime ::  2018-10-12 17:50:10
# Likes Count ::  5
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @mr2amc: Dear Colleagues,
# @mr2amc Deadline extended until Oct 18, 2018.
# Please consider submitting your research contribution to the 2nd…
# Created Datetime ::  2018-10-12 03:48:01
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congratulations Puneet Mathur @punnibhai , Meghna Ayyar @Leomi7, Dr. Rajiv Ratn Shah @RatnRajiv, and Dr. Shree Gopal Sharma on getting their paper (Harnessing AI for Kidney Glomeruli Classification) accepted to 20th IEEE International Symposium on Multimedia.
# #ISM #MIDAS #IIITD
# Created Datetime ::  2018-10-12 03:37:46
# Likes Count ::  10
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  MTech and Ph.D. students of @IIITDelhi, if you are interested in pursuing 6 months research internship at National Institute of Informatics (NII), Japan then you may contact @midasIIITD founder Dr. @RatnRajiv for the same.
#
# Last date: 31 Oct
#
# #research #internship #tokyo #japan
# Created Datetime ::  2018-10-10 17:56:45
# Likes Count ::  7
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Thank you, @nvidia for your support. https://t.co/teGlvxhCKr
# Created Datetime ::  2018-10-09 17:25:48
# Likes Count ::  13
# Retweet Count ::  3
# No of Images ::  1
# **********
# ----------
# Tweet Text ::  RT @mr2amc: MR2AMC'18: Multimodal Representation, Retrieval, and Analysis of Multimedia Content in Social Media
# Deadline: October 7,…
# Created Datetime ::  2018-10-06 15:22:39
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @OriolVinyalsML: Best GAN samples ever yet? Very impressive ICLR submission! BigGAN improves Inception Scores by &gt;100.
#
# Paper: https://t…
# Created Datetime ::  2018-09-30 07:22:30
# Likes Count ::  0
# Retweet Count ::  575
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @radamihalcea: I compiled a list of top ten reasons to study Computer Science, and with the help of talented graphic designers, turned t…
# Created Datetime ::  2018-09-30 07:20:56
# Likes Count ::  0
# Retweet Count ::  47
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Too many Turing awards, Field medals, Abel prizes, and Nevanlinna prizes in a frame. 😆
# Thank you, @HLForum for providing a p…
# Created Datetime ::  2018-09-28 21:36:34
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @RatnRajiv: Thank you, @HLForum for organizing a wonderful conference with laureate in computer science and mathematics.
# It could not b…
# Created Datetime ::  2018-09-28 21:17:16
# Likes Count ::  0
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  Congrats @midasIIITD student @Simcyy for getting selected to @Adobe Research for her summer internship in 2019.
# Created Datetime ::  2018-09-22 20:53:27
# Likes Count ::  4
# Retweet Count ::  1
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @mr2amc: MR2AMC'18: Multimodal Representation, Retrieval, and Analysis of Multimedia Content in Social Media
#
#   Deadline: October 7,…
# Created Datetime ::  2018-09-12 09:48:48
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @mr2amc: Please submit your research papers on multimedia, social media, and multimodal computing to @mr2amc 2018. More details can be f…
# Created Datetime ::  2018-09-10 17:46:41
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: Summarizing some recent developments in word embeddings #nlp https://t.co/XykpLifuop
# Created Datetime ::  2018-09-10 05:37:01
# Likes Count ::  0
# Retweet Count ::  3
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @debanjanbhucs: Excellent post for those working on word embeddings #NLP #MachineLearning  https://t.co/xENTzh7GrZ
# Created Datetime ::  2018-09-09 05:14:58
# Likes Count ::  0
# Retweet Count ::  2
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  @sharmadrishti @IIITDelhi @emnlp2018 Thank you, @sharmadrishti @midasIIITD @midasIIITD @RatnRajiv
# Created Datetime ::  2018-09-06 09:59:01
# Likes Count ::  1
# Retweet Count ::  0
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @IIITDelhi: Congratulations team @midasIIITD
# for getting 4 papers accepted to @emnlp2018 workshops.  1) Offensive Tweets Classification,…
# Created Datetime ::  2018-09-06 05:08:53
# Likes Count ::  0
# Retweet Count ::  4
# No of Images ::  None
# **********
# ----------
# Tweet Text ::  RT @kdnuggets: Auto-Keras, or How You can Create a #DeepLearning Model in 4 Lines of Code #KDN https://t.co/A1FgKE0ZKA
# Created Datetime ::  2018-09-05 18:05:33
# Likes Count ::  0
# Retweet Count ::  11
# No of Images ::  None
# **********
